# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Wed Apr 01 2020
#
# CPython 3.7.7
# IPython 7.13.0
#
# numpy 1.18.1
# scipy 1.4.1
# sklearn 0.22.1
# pandas 1.0.3
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-91-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
# %matplotlib inline
import pandas as pd 
import numpy as np 
import seaborn as sns

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
# Out:
# /home/db/myLab/IRIS_PROJECT/src

# %%
# data_frame = os.path.join(PROJ_ROOT,'data','raw','iris.csv')
data_frame = '../../data/raw/iris.csv'
dframe = pd.read_csv(data_frame,header=None)

# %%
dframe.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
dframe.columns = ['x0','x1','x2','x3','y']
dframe.head()
# Out:
#     x0   x1   x2   x3            y
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
sns.pairplot(dframe,vars=['x0','x1','x2','x3'],hue='y')
